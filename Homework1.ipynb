# %% [markdown]
# **Wesleyan University ASTR 210**
#
# # Homework 1
#
# Work through this Python notebook, writing your own code where indicated to solve the problems.  When you are finished, save this document and upload the completed notebook to the course Moodle (in .ipynb format).
#
# In this homework, your ultimate goal is to construct a "catalog" of four stars (Sirius, Rigel, Betelgeuse, and Polaris) which contains the following physical properties of each star:
# - Apparent magnitude (floating point number, e.g., 0.45, -1.3)
# - Spectral type (character string, e.g., 'A', 'O', 'M')
# - Whether or not it has a binary companion (Boolean, True or False)
#
# Your catalog will take the form of a python *dictionary* with keys 'name', 'm', 'spectype', and 'has_companion', which each retrieve a *list* of the corresponding properties of the four stars.
#
# We will start off by just considering the properties of a single star (Sirius A) and do some math with those properties, then we'll construct our full catalog and work with that catalog to compare the properties of the stars against each other.
#
# After submission, your work will be graded by executing the cells in order from top to bottom and examining the output.  (I have left in the outputs you are aiming to produce, so that you know what you're shooting for.)  Sometimes, re-running from top to bottom can reveal problems, if you have been jumping around between cells while working and executing them in a different order than they appear!  To check your work, I suggest that you *also* run it clean from top to bottom before submitting just to make sure everything works the way you think it should.  To do that, go to Kernel -> Restart Kernel and Run All Cells, then look at the output to make sure it's what you expect.
#
# Be sure to comment your code to explain (both to yourself and us) what you are doing and why.  Using comments is very likely to help you get more partial credit in the event you have done something incorrect, because we will be able to understand your reasoning.

# %% [markdown]
# ## Properties of Sirius A (20 points)
#
# Sirius A is the brightest star in Earth's sky, with an apparent magnitude of -1.46.  It is an A-type star with an absolute (i.e., intrinsic) magnitude of 1.43, and it has a faint binary companion, Sirius B, which is a white dwarf.  Below we'll define a few variables that describe these properties.
#
# ![image.png](attachment:82043ad0-b5da-4cf3-8633-5e15546888eb.png)
#
# **(4 points)** Fill in the properties of Sirius A in the cell below such that sirius_apparent_magnitude and sirius_absolute_magnitude are float-type variables, sirius_spectral_type is a string variable, and sirius_has_companion is a Boolean variable.

# %%
sirius_apparent_magnitude = -1.46 # YOUR CODE HERE
sirius_absolute_magnitude = 1.43 # YOUR CODE HERE
sirius_spectral_type = 'A'# YOUR CODE HERE
sirius_has_companion = True # YOUR CODE HERE

# %% [markdown]
# **(4 points)** Write code below that will print out the type of each of the four variables you defined above, to check your work.

# %%
print(type(sirius_apparent_magnitude))
print(type(sirius_absolute_magnitude))
print(type(sirius_spectral_type))
print(type(sirius_has_companion))
# YOUR CODE HERE
# Out:
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# **(6 points)** We can calculate how far away Sirius A's given its apparent and absolute magnitudes.  The two are related as:
# $$m - M = 5 \log_{10}(d/10)$$
# or
# $$d = 10^{\left(\frac{m-M}{5} + 1\right)}$$
# where $m$ = apparent magnitude, $M$ = absolute magnitude, and $d$ = distance in parsecs.
#
# Write an expression below that calculates the distance to Sirius A in parsecs.

# %%
m = sirius_apparent_magnitude
M = sirius_absolute_magnitude
sirius_distance = 10**((m-M)/5 + 1)
# YOUR CODE HERE

# %%
print(sirius_distance)
# Out:
# 2.6424087573219466

# %% [markdown]
# **(6 points)** The magnitude system can be a little weird, so let's convert that absolute magnitude to something more tangible: luminosity.  Absolute magnitude and luminosity are related as:
# $$L = 10^{\left(\frac{4.74-M}{2.5}\right)}$$

# %% [markdown]
# where $L$ = luminosity in units of solar luminosity $L_\odot$.
#
# Write an expression below that calculates the luminosity of Sirius A in units of $L_\odot$.

# %%
sirius_luminosity = 10**((4.74-M)/2.5)
                        # YOUR CODE HERE

# %%
print(sirius_luminosity)
# Out:
# 21.08628149933291

# %% [markdown]
# ## Constructing a star catalog (35 points)
#
# Now, let's add a few more stars to our data collection.  Before doing so, we'll want to convert our information about Sirius into *lists* instead of single variables, so that we can easily add another star whenever we want.
#
# **(6 points)** Let's make four lists: one for the *name* of each star, one for the *apparent magnitude* of each star, one for the *spectral type* of each star, and one indicating whether the star *has a companion* or not.  We will initialize each list with a single element corresponding to the properties of Sirius.
#
# Below, I have initialized the lists for names and apparent magnitudes.  Finish the lines which **initialize the lists for spectral type and companion status, using the variables we have already defined for Sirius A above**.

# %%
names = ['Sirius']
apparent_magnitudes = [sirius_apparent_magnitude]
spectral_types = [sirius_spectral_type]# YOUR CODE HERE
has_companion =[sirius_has_companion]

# %%
print(names)
print(apparent_magnitudes)
print(spectral_types)
print(has_companion)
# Out:
# ['Sirius']
# [-1.46]
# ['A']
# [True]

# %% [markdown]
# **(6 points)** Rigel is a blue supergiant star of spectral type B located in the bottom right corner of the constellation Orion.  It has an apparent magnitude of 0.13, and has multiple companions.
#
# ![image.png](attachment:1ca030c7-ce2a-4adf-a5a7-cbabd0df6cc8.png)
#
# Add Rigel's information to our catalog lists below.  I have done the first one for you.

# %%
names.append('Rigel')
apparent_magnitudes.append(0.13)# YOUR CODE HERE: add to apparent_magnitudes
spectral_types.append('B')# YOUR CODE HERE: add to spectral_types
has_companion.append(True)
# YOUR CODE HERE: add to apparent_magnitudes
# YOUR CODE HERE: add to spectral_types
# YOUR CODE HERE: add to has_companion (remember, this is a Boolean variable!)

# %%
print(names)
print(apparent_magnitudes)
print(spectral_types)
print(has_companion)
# Out:
# ['Sirius', 'Rigel']
# [-1.46, 0.13]
# ['A', 'B']
# [True, True]

# %% [markdown]
# **(10 points)** Betelgeuse is the red supergiant star (of spectral type M) which you see in the upper left corner of Orion.  It has an apparent magnitude of 0.5, and is a single star with no companions.
#
# Polaris (or the "North Star") is an F-type star with an apparent magnitude of 1.98, and it has a binary companion.
#
# Add the information for Betelguese and Polaris to our catalogs.

# %%
names.append('Betelgeuse')
names.append('Polaris')
apparent_magnitudes.append(0.5)
apparent_magnitudes.append(1.98)
spectral_types.append('M')
spectral_types.append('F')
has_companion.append(False)
has_companion.append(True)
# YOUR CODE HERE (8 lines, one for each piece of information being added)

# %%
print(names)
print(apparent_magnitudes)
print(spectral_types)
print(has_companion)
# Out:
# ['Sirius', 'Rigel', 'Betelgeuse', 'Polaris']
# [-1.46, 0.13, 0.5, 1.98]
# ['A', 'B', 'M', 'F']
# [True, True, False, True]

# %% [markdown]
# Great, now we have data for all four stars in our catalog!  It is a little cumbersome to have all of these separate lists, though -- let's collect them into a dictionary.
#
# **(8 points)** Below, I have written code to initialize an empty dictionary and add the lists of names and apparent magnitudes to it.
#
# Fill in the lines to **add the lists for spectral type and companion status to the dictionary**.

# %%
# Initialize an empty dictionary
star_catalog = {}   
# Add the list of names to the dictionary with the keyword "names"
star_catalog['names'] = names  
# Add the list of apparent magnitudes to the dictionary with the keyword "m"
star_catalog['m'] = apparent_magnitudes 

star_catalog['types'] = spectral_types# YOUR CODE HERE: Add the list of spectral types to the dictionary with the keyword "types"
star_catalog['has_companion'] = has_companion # YOUR CODE HERE: Add the list of spectral types to the dictionary with the keyword "has_companion"

# %%
print(star_catalog)
# Out:
# {'names': ['Sirius', 'Rigel', 'Betelgeuse', 'Polaris'], 'm': [-1.46, 0.13, 0.5, 1.98], 'types': ['A', 'B', 'M', 'F'], 'has_companion': [True, True, False, True]}

# %% [markdown]
# **(5 points)** The lists of data can now be accessed from the dictionary star_catalog by using the keywords we defined.  An example which prints out the list of star names is below.  Fill in the second line to print out the list of spectral types in the same way.

# %%
print(star_catalog['names'])
print(star_catalog['types'])# YOUR CODE HERE: print list of spectral types from the
# Out:
# ['Sirius', 'Rigel', 'Betelgeuse', 'Polaris']
# ['A', 'B', 'M', 'F']

# %% [markdown]
# ## Accessing information in the catalog (45 points)
#
# We now have all of our data in one, organized "data structure."  Let's see how we might retrieve and use that data in practice.
#
# **(2 points)** Recall that individual elements in a list can be accessed by calling their *index*, starting at index 0 for the first element and counting up by 1 for each subsequent element.  Below, **set the value of the variable istar to the index corresponding to Betelgeuse** in our data structure.  (You will be able to tell if you were correct because the subsequent line will print out the name of the star you've identified.)

# %%
istar = 2 # YOUR CODE HERE
print(names[istar])
# Out:
# Betelgeuse

# %% [markdown]
# **(4 points)** In the cell above, you may have noticed that the line I wrote printed out the star name out of our original *list* of names, not from the dictionary star_catalog we just painstakingly created.  **Write another print statement that prints the same star name, but does so by accessing the star_catalog dictionary** this time.  (Hint: first access the list of names using the keyword the same as you did two cells up, then index that list to retrieve the individual element.)

# %%
print(star_catalog['names'][istar])# YOUR CODE HERE
# Out:
# Betelgeuse

# %% [markdown]
# **(5 points)** Use the variable istar to create a string variable called print_index which reads, "We are currently looking at index (VALUE OF ISTAR)" where (VALUE OF ISTAR) is... the value of istar.  (Hint: you will need to *cast* istar to a string in order to concatenate it with the rest of the sentence.)

# %%
print_index = 'We are currently looking at index %s' % istar # YOUR CODE HERE
print(print_index)
# Out:
# We are currently looking at index 2

# %% [markdown]
# **(5 points)** Use the index istar and the dictionary star_catalog to create a string variable called print_name which reads, "Index (VALUE OF ISTAR) corresponds to the star (NAME OF STAR AT INDEX ISTAR)".  (Hint: to get the name of the star, you can use the same method you did two cells previously.)

# %%
print_name = 'Index %s corresponds to the star %s' % (istar, star_catalog['names'][istar])# YOUR CODE HERE
print(print_name)
# Out:
# Index 2 corresponds to the star Betelgeuse

# %% [markdown]
# **(5 points)** Use the index istar and the dictionary star_catalog to create a string variable called print_type which reads, "(NAME OF STAR AT INDEX ISTAR) is spectral type (SPECTRAL TYPE OF STAR AT INDEX ISTAR)"

# %%
print_type = '%s is spectral type %s' %(star_catalog['names'][istar], star_catalog['types'][istar])# YOUR CODE HERE
print(print_type)
# Out:
# Betelgeuse is spectral type M

# %% [markdown]
# **(8 points)** Now that we've constructed all these strings, let's change the value of the index istar and print out the information for another star.
#
# **Set istar to the index corresponding to Polaris, re-define the string variables according to that new index, and print them out.**
#
# (If you defined the string variables correctly using istar, you should be able to directly copy the same lines of code from above.)

# %%
istar = 3
print_index = 'We are currently looking at index %s' % istar
print_name = 'Index %s corresponds to the star %s' % (istar, star_catalog['names'][istar])
print_type = '%s is spectral type %s' %(star_catalog['names'][istar], star_catalog['types'][istar])

print (print_index)
print (print_name)
print (print_type)# YOUR CODE HERE (3 lines): print out print_index, print_name,
# Out:
# We are currently looking at index 3
# Index 3 corresponds to the star Polaris
# Polaris is spectral type F

# %% [markdown]
# (If you defined everything correctly, the last line should read, "Polaris is spectral type F".)  Now you should be able to get the information for any star in the catalog simply by changing the value of istar in the first line and re-executing the cell!

# %% [markdown]
# Finally, let's use our data structure to compare the brightnesses of two stars from our catalog.  Betelgeuse and Rigel are the two brightest stars in the constellation Orion.  Which is brighter?
#
# **(6 points)** Set the values of istar1 and istar2 to the indices of Betelgeuse and Rigel respectively.  Then use those indices to retrieve their apparent magnitudes from the star catalog.

# %%
istar1 = 2 # YOUR CODE HERE: index of Betelgeuse
istar2 = 1 # YOUR CODE HERE: index of Rigel
mag1 = star_catalog['m'][istar1]# YOUR CODE HERE: apparent magnitude at index istar1
mag2 = star_catalog['m'][istar2]# YOUR CODE HERE: apparent magnitude at index istar2
print(mag1, mag2)
# Out:
# 0.5 0.13

# %% [markdown]
# **(5 points)** Define a Boolean variable brighter_than which is True if star1 is brighter than star2, and False otherwise.  Note: because the magnitude system is weirdly defined (see above), the star with the *lower* magnitude is the brighter one.

# %%
brighter_than = mag1 < mag2 # YOUR CODE HERE

# %% [markdown]
# **(5 points)** Use istar1, istar2, star_catalog, and brighter_than to define a string variable called print_brighter which reads,
#
# "The statement '(NAME OF STAR AT INDEX ISTAR1) is brighter than (NAME OF STAR AT INDEX ISTAR2)' is (VALUE OF BRIGHTER_THAN)",
#
# and print it out. (Note that you will need to use *escape characters* to get the single parentheses to appear.)

# %%
print_brighter = 'the statement %s is brighter than %s is %s' %(star_catalog['names'][istar1], star_catalog['names'][istar2], brighter_than)# YOUR CODE HERE
print(print_brighter)
# Out:
# the statement Betelgeuse is brighter than Rigel is False

# %% [markdown]
# (By the way, this statement is not actually correct if we are bring very strict - Betelgeuse is a variable star whose brightness fluctuates over time, so sometimes it is brighter than Rigel and sometimes not.  But this statement describes its *typical* brightness with respect to Rigel.)

# %% [markdown]
# And with that, you have completed your first homework set for this class!  As mentioned at the top, I suggest you go to Kernel -> Restart Kernel and Run All Cells to check your work, then save and upload this completed document to Moodle.
